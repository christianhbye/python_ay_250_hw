# %% [markdown]
# # Homework 1: Numpy, Scipy, Pandas
#
# ### Due Tues Feb 1, 2022 @ 8pm

# %% [markdown]
# ## #0: Get set up with your environment to work on and submit homework
#
# a. Create a new homework repository at github
#
# <img src="data/screenshot_1.png">
#
# Name your repo something sensible (e.g., python-ay250-homeworks). Given your Berkeley affiliation you should be able to get private repos if you'd like.
#
# <img src="data/screenshot_2.png">
#
#
# b. Clone this repo locally and make a directory for this week's homework:
#
# ```bash
# cd /class/directories ## this will be different on your machine...whereever you want to keep your work.
#
# # change <username> to your github username:
# git clone https://github.com/<username>/python-ay250-homework.git
# cd python-ay250-homework
# mkdir hw_1
# echo "hw_1 README" >> hw_1/README.md
# git add hw_1/README.md
# git commit hw_1/README.md -m "added hw_1 directory"
# git push
# ```
#
# c. Copy this notebook into your `hw_1` folder from a local version of the python-seminar repo
#
# ```bash
# cd /class/directories
# git clone https://github.com/profjsb/python-seminar.git
# cd python-seminar
# git pull
# cp -r Homeworks/hw_1/* /class/directories/python-ay250-homework/hw_1/
# ```
#
# d. Get working! Be sure to check in your work as often as you'd like
#
# ```bash
# cd /class/directories/python-ay250-homework
# git add hw_1/<whatever>
# git commit <whatever> -m "this is a check in"
# git push
# ```
#
# e. To submit your work, go to this form to register your homework Repo URL (https://forms.gle/z9XZqCD5Ra9ikTGQ8). If you've made your repo private, you'll need to add us as collaborators to the repo.  Our Github handles are `@profjsb` and `@elliesch`.

# %% [markdown]
# ## #1:  Super-resolution imaging
#
# Obtaining several snapshots of the same scene, from microscopes to telescopes, is useful for the postprocessing increase of signal to noise: by summing up imaging data we can effectively beat down the noise. Interestingly, if we image the same scene from different vistas we can also improve the clarity of the combined image. Being able to discern features in a scene from this combination effort is sometimes called super-resolution imaging.
#
# Here, we'll combine about 4 seconds of a shaky video to reveal the statement on a license plate that is not discernable in any one frame.
#
# <img src="Data/im2-1.png">
#
# A tarball of the data is at: https://zenodo.org/record/5889322/files/homework1_data.tgz?download=1 (Zenodo page for the course: https://zenodo.org/record/5889322). This file is also in the read-only directory on `astro.datahub.berkeley.edu`.
#
# ```bash
# tar -xvzf homework1_data.tgz  # do NOT check this files into git...
# ```

# %% [markdown]
# **Problem 1** Read in each image into a `numpy` array. Resize each frame to be 3 times larger in each axis (ie. 9 times larger images). Using `scipy.signal.fftconvolve` find the offsets of each frame with respect to the first frame. Report those offsets to 2 decimal places.
#
#    - Hint0: you can use `PIL` to read the images or `matplotlib.pyplot.imread`
# ```python
# from PIL import Image
# array = Image.open(fname).convert('L')
# ```
#    - Hint1: you'll need to figure out how to resize a numpy array. Check out PIL.Image.resize...
#    - Hint2: you'll want to reverse the second image when doing the convolution: `scipy.signal.fftconvolve(im1, im2[::-1, ::-1])`
#    - Hint3: you'll need to figure out how to identify the peak of the fft convolution to find the offsets between images

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from scipy import signal, ndimage

# %%
# look at an example image
im=Image.open('./data/Data/im2-0.png').convert('L')
im=np.array(im.resize(tuple(3*s for s in im.size)))

plt.figure()
plt.imshow(im, interpolation='none')
plt.colorbar()
plt.show()

# %% [markdown]
# As seen in the example image above, the images have horizontal stripes above and below without information which are interpreted as the brightest possible pixels by PIL and numpy. These might skew the correleation between two uncropped images because a vertical shift (which would result in multypling some of these very bright pixels by the padded 0s on the top of the shifted image) would be severley penalized. Albeit to lesser extent, we might get the same effect for horizontal shifts due to the left edge being much brighter than the right edge.
#
# Since we expect the shift to be small compared to the image size, we can safely crop the image significantly and only correlate the cropped center of the images:

# %%
# crop image
crop_x,crop_y=250,250
cropped=im[crop_y:-crop_y, crop_x:-crop_x]
plt.figure()
plt.imshow(cropped, interpolation='none')
plt.colorbar()
plt.show()

# %%
# initialize arrays to store the images, correlations, and offsets

N_images=100  # total number of images

dims=np.array(cropped.shape)  # get image size
im_arrays=np.empty((N_images, *dims))  # make array of resized images

# shape of correlation (using mode='full')
cdims=2*dims-1
corrs=np.empty((N_images, *cdims))
offsets=np.zeros((N_images, 2))  # array of offsets along each dimension

# %% [markdown]
# We will use the correlation mode that Scipy defines as "full". This mode involves padding 0's wherever the images don't overlap. Originally, the brightness of the pixels range from 0 to 255, meaning that the padded areas effectively are completely black. Hence, the peak of the correlation might be skewed to small or no shifts between the images, as there would be less 0-padding and effectively more pixels that contribute to the correlation.
#
# To mitigate this issue, we normalize the pixel brightness by mapping them from the original range to [-1, 1].

# %%
def normalize_image(image):
    """
    Linear map of pixel brightness to [-1, 1]
    """
    image=image.copy().astype(np.float64)
    normalized=image-image.min()
    normalized/=image.max()-image.min()
    normalized=2*normalized-1
    return normalized

# %%
# the image looks the same, but note the colorbar
plt.figure()
plt.imshow(normalize_image(cropped), interpolation='none')
plt.colorbar()
plt.show()

# %%
for i in range(N_images):  # loop over images
    im_path='./data/Data/im2-'+str(i)+'.png'
    im=Image.open(im_path).convert('L')  # load image
    im=im.resize(tuple(3*s for s in im.size))  # resize to 3x size along each axis
    im=np.array(im)[crop_y:-crop_y, crop_x:-crop_x]  # crop and convert to numpy array
    im=normalize_image(im)
    im_arrays[i]=normalize_image(im)
    # find offset wrt to first frame
    if i>0:
        corr=signal.correlate(im_arrays[0], im, mode='full')  # automatically uses the FFT and correlation theorem
        corrs[i]=corr
        # compute shift
        offsets[i]=np.array(np.unravel_index(corr.argmax(), corr.shape))-dims+1

# %%
# plot the output of the correlation for every 10 images
# the first output is the autocorrelation of the first image
# subsequent outputs show a peak that indicates the shift
for i in range(10):
    plt.figure()
    plt.imshow((convs[i*10]), interpolation='none')
    plt.colorbar()
    plt.show()

# %% [markdown]
# The offsets are given in the variable "offsets" in units of the rescaled pixels. The n'th row is the offset of the image labelled im-n relative to im-0. We print them out in units of the original pixels below:

# %%
print('Offsets:\n {}'.format(np.array2string(offsets/3, precision=2, separator='\t', floatmode='fixed')))
# Out:
# Offsets:
#  [[  0.00	  0.00]
#  [  2.67	-13.00]
#  [ 40.67	 -2.33]
#  [ 59.00	 11.00]
#  [  0.00	  0.67]
#  [  2.33	 11.00]
#  [ 44.67	 24.00]
#  [  0.00	-40.00]
#  [ 21.67	-12.00]
#  [  0.00	-27.00]
#  [ 34.67	 -2.67]
#  [ 19.00	-55.33]
#  [ 21.00	 -8.00]
#  [  8.33	-34.67]
#  [ 18.67	 -2.67]
#  [ 58.67	 -6.33]
#  [ 38.00	 11.33]
#  [ 18.67	-24.33]
#  [ 36.00	-32.00]
#  [ 13.67	 -8.00]
#  [-16.00	-26.67]
#  [ 26.33	-36.67]
#  [ 16.00	-32.33]
#  [  5.33	-35.67]
#  [ 37.67	-21.00]
#  [ 40.33	-21.00]
#  [  0.00	-55.67]
#  [ 15.33	 16.33]
#  [ 17.67	 18.67]
#  [ 45.67	  0.00]
#  [ 27.00	-42.33]
#  [ 37.67	 29.33]
#  [ 27.33	  5.67]
#  [ 56.00	-19.00]
#  [ -0.33	-37.33]
#  [ 35.00	  0.00]
#  [ 52.33	 21.33]
#  [ 32.67	 17.00]
#  [ 18.33	-15.00]
#  [ 15.00	 45.00]
#  [ 27.00	 -3.00]
#  [ 37.33	 -0.67]
#  [ 30.33	  4.67]
#  [ 26.67	 -8.33]
#  [ 20.67	  3.33]
#  [  2.33	-49.33]
#  [ 16.67	-30.67]
#  [ 26.67	-33.00]
#  [ 45.67	  9.67]
#  [ 45.67	 -2.00]
#  [ 43.33	  2.67]
#  [ 18.67	-19.67]
#  [ 21.00	-36.67]
#  [  0.00	-10.33]
#  [ 29.33	-45.67]
#  [ 21.67	-12.33]
#  [ -4.67	  7.67]
#  [  0.00	-21.33]
#  [  7.67	 -8.00]
#  [ 37.67	-34.67]
#  [  7.67	-23.67]
#  [ 64.67	 -7.33]
#  [-16.33	-14.67]
#  [  9.67	-29.67]
#  [ 16.00	-40.33]
#  [  5.33	 -2.33]
#  [ -2.67	-48.33]
#  [ 35.00	 12.33]
#  [ 35.33	-20.00]
#  [ 21.33	-19.00]
#  [ 18.33	 -0.67]
#  [  5.33	 -1.33]
#  [ 26.00	 -3.67]
#  [  9.67	-36.67]
#  [ -2.67	-19.00]
#  [ 23.00	  2.67]
#  [ -8.00	 -3.67]
#  [ 24.33	-22.00]
#  [ 19.33	-24.33]
#  [ 42.33	-13.67]
#  [ 19.00	-31.67]
#  [ 31.67	-10.33]
#  [ 48.00	 13.00]
#  [ 18.00	-25.00]
#  [-18.67	  0.00]
#  [ 36.00	  3.00]
#  [ 69.00	 -3.00]
#  [ 62.33	 -5.33]
#  [ 22.00	 30.00]
#  [  5.00	-18.67]
#  [ 61.67	 30.00]
#  [ 29.67	  3.67]
#  [ 37.67	 18.67]
#  [ 26.67	-51.33]
#  [ 40.00	 16.00]
#  [  0.00	-18.33]
#  [ 35.00	 -6.33]
#  [  5.33	  5.67]
#  [ 48.00	 15.67]
#  [ 31.00	 -2.33]]

# %% [markdown]
# **Problem 2** Shift each image to register the frames to the original (expanded in size) frame. You should, in general, be shifting by subpixel offsets. You might want to look at `scipy.ndimage.interpolation.shift`

# %%
# make an array for the cropped and shifted images
shifted_ims=np.empty_like(im_arrays)
for i in range(len(im_arrays)):
    shifted_ims[i]=ndimage.shift(im_arrays[i], offsets[i])  # shift each image by its offset

# %%
# look at 10 images
for i in range(10):
    plt.figure()
    plt.imshow(shifted_ims[i], interpolation='none')
    plt.show()

# %% [markdown]
# **Problem 3** Combine all the registered images to form a super-resolution image. What does the license plate read?

# %%
# add the pixels across images to get the combined image

plt.figure()
plt.imshow(shifted_ims.sum(axis=0), interpolation='none')
plt.show()

# %% [markdown]
# The license plate reads: "IM A CAR"

# %%
# let's look at the full image
fullsize=Image.open('./data/Data/im2-0.png').convert('L').size
super_image=np.zeros(3*np.array(fullsize))

for i in range(N_images):  # loop over images
    im_path='./data/Data/im2-'+str(i)+'.png'
    im=Image.open(im_path).convert('L')  # load image
    im=np.array(im.resize(tuple(3*s for s in im.size)))  # resize to 3x size along each axis
    M,m=im.max(), im.min()  # these will be needed for unnormalization
    shift_im=ndimage.shift(im, offsets[i])
    super_image+=shift_im

# %%
super_image=Image.fromarray(super_image/N_images).convert('L')
super_image=super_image.resize(tuple(s//3 for s in super_image.size))

# %%
super_image
# Out:
# <PIL.Image.Image image mode=L size=288x288 at 0x7F7ED42341F0>

# %% [markdown]
# # #2: An elementary introduction to spectral audio compression
#
# In this problem, we'll explore the very basics of audio compression in the spectral domain using numpy and scipy. We'll do a bit of visualization with matplotlib, but since that is covered later in the course, we'll provide those functions for you.
#
# Audio compression is a large and complex topic, and the design of a format for compressed audio such as the popular [MP3](http://en.wikipedia.org/wiki/MP3) is too complex to cover in detail here. However, we will introduce the basic tools that most such compression formats use, namely:
#
# 1. Converting the input signal to the frequency domain by taking a Fast Fourier Transform (FFT).
#
# 2. Dropping information in the frequency domain, resulting in a smaller amount of data.
#
# 3. Reconstructing back the signal in the time domain from this smaller representation of the signal.
#
# Steps 1 and 2 above are the 'encoding' part of signal compression, and step 3 is the 'decoding' part. For this reason, the tools that perform these steps are typically referred to as signal 'codecs', short for encoders/decoders.
#
# Note that here we say 'signal': while MP3 is an audio format, the same ideas apply to the compression of digital images with formats such as JPEG and video.  Virtually all multimedia technologies we use today, from audio players to cell phones, digital cameras and YouTubeVideo, are based on sophisticated extensions and applications of these simple ideas.

# %% [markdown]
# Let's first load the plotting tools and importing some tools we'll need later:

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# we'll need some path manipulations later on
import os

# %% [markdown]
# We define a simple utility function to listen to audio files right in the browser:

# %%
def Audio(fname):
    """Provide a player widget for an audio file.
    
    Parameters
    ==========
    fname : string
      Filename to be played.
      
    Warning
    =======
    
    Browsers cache audio very aggressively. If you change an
    audio file on disk and are trying to listen to the  new version, you 
    may want to 
    """
    from IPython.display import HTML, display
    
    # Find out file extension and deduce MIME type for audio format
    ext = os.path.splitext(fname)[1].replace('.', '').lower()
    mimetype = 'audio/' + ('mpeg' if ext == 'mp3' else ext)
    
    tpl = """<p>{fname}:</p>
<audio controls>
    <source src="files/{fname}" type="{mimetype}">

Your browser does not support the Audio element; you can play 
<a href="files/{fname}">this file</a> manually.
</audio>
"""
    display(HTML(tpl.format(**locals())))

# %% [markdown]
# We also define a convenience wrapper around `plt.specgram`, [matplotlib's spectrogram function](http://matplotlib.org/api/mlab_api.html#matplotlib.mlab.specgram), with a colorbar and control over the color limits displayed. This will make it easier to compare across different signals with the same colors for all inputs.

# %%
def specgram_cbar(x, title=None, clim=(0, 80) ):
    """Plot spectrogram with a colorbar and range normalization.
    
    Call matplotlib's specgram function, with a custom figure size, 
    automatic colobar, title and custom color limits to ease 
    comparison across multiple figures.
    
    Parameters
    ==========
    x : array
      One-dimensional array whose spectrogram should be plotted.
      
    title : string
      Optional title for the figure.
      
    clim : 2-tuple
      Range for the color limits plotted in the spectrogram.
    """
    f = plt.figure(figsize=(10,3))
    plt.specgram(x, Fs=2)
    plt.colorbar()
    plt.clim(*clim)
    if title is not None:
        plt.title(title)
    plt.show()

# %% [markdown]
# **Problem 1**: Use the `Audio` function above to listen to the signal we will be experimenting with, a simple voice recording stored in the file `Homeworks/hw1/data/voice.wav`.
#
# Note: if your browser doesn't support audio, you may try a different browser.   We've tested current versions of Chrome and Firefox, and it works OK with both.

# %%
Audio('data/voice.wav')
# Out:
# <p>data/voice.wav:</p>
# <audio controls>
#     <source src="files/data/voice.wav" type="audio/wav">
#
# Your browser does not support the Audio element; you can play
# <a href="files/data/voice.wav">this file</a> manually.
# </audio>

# %% [markdown]
# **Problem 2**: Write a function to compress a 1-d signal by dropping a fraction of its spectrum.
#
# You can drop the smallest components by setting their values to zero.
#
# *Hints*:
#
# - look at the `np.fft` module, keeping in mind that your input signal is real.
# - look at the `argsort` method of numpy arrays.

# %% [markdown]
# We Fourier transform the signal to frequency domain, set the high-frequency contributions to 0, and inverse Fourier transform back to time domain.

# %%
def compress_signal(x, fraction):
    """Compress an input signal by dropping a fraction of its spectrum.
    
    Parameters
    ==========
    x : array
      1-d real array to be compressed
      
    fraction : float
      A number in the [0,1] range indicating which fraction of the spectrum
      of x should be zeroed out (1 means zero out the entire signal).
      
    Returns
    =======
    x_approx : array
      1-d real array reconstructed after having compressed the input.
    """
    x_tilde=np.fft.rfft(x)  # real FFT since input is real (already sorted low to high frequencies)
    # <fraction> of frequency indices with smallest contributions to the power:
    power=np.abs(x_tilde)**2
    small_idx=np.argsort(power)[:int(fraction*len(power))]
    compressed_x_tilde=x_tilde.copy()
    compressed_x_tilde[small_idx]=0  # set the small contributions to 0
    # inverse FFT to get the compressed time domain signal:
    if x.dtype in ['int8', 'int16', 'int32', 'int64']:  # casting to int always round to 0 so need to round manually
        compressed=np.round(np.fft.irfft(compressed_x_tilde)).astype(x.dtype)
    else:
        compressed=np.fft.irfft(compressed_x_tilde).astype(x.dtype)
    assert compressed.dtype==x.dtype
    return compressed

# %% [markdown]
# As a quick visual check (not that this is *not* a formal test of correctness), experiment with a simple random signal by changing the compression ratio and plotting both the signal and the compressed version:

# %%
x = np.random.rand(128)

# %%
fraction = 0.8  # play changing this in the 0-1 range

xa = compress_signal(x, fraction)

plt.figure(figsize=(12,3))
plt.plot(x, alpha=0.5, lw=2, label='original')
plt.plot(xa, lw=2, label='compressed {0:.0%}'.format(fraction))
plt.legend();

# %% [markdown]
# **Problem 3**: Write a function that will compress an audio file by a dropping a fraction of its spectrum, writing the output to a new file.
#
# If the input file is named `a.wav` and the compression fraction is 0.9, the output file should be named `a_comp_0.9.wav`.
#
# *Hints:*
#
# - look at the `scipy.io` module for routines dealing with files in `wav` format.
#
# - you may need to use the `astype` method of numpy arrays to get the correct data type for `wav` files.

# %%
from scipy.io import wavfile

# %%
def compress_wav(fname, fraction):
    """Compress an audio signal stored in an input wav file.
    
    The compressed signal is returned as a numpy array and automatically written 
    to disk to a new wav file.
    
    Parameters
    ==========
    fname : string
      Name of the input wav file
      
    fraction : float
      Fraction of input data to keep.
      
    Returns
    =======
    rate : int
      Bit rate of the input signal.

    x : array
      Raw data of the original input signal.
      
    x_approx : array
      Raw data of the compressed signal.
      
    new_fname : string
      Auto-generated filename of the compressed signal.
    """
    
    rate,sig=wavfile.read(fname)
    compressed=compress_signal(sig, fraction)
    out_fname=fname[:-len('.wav')]+'_comp_'+str(fraction)+'.wav'
    wavfile.write(out_fname, rate, compressed)
    return rate, sig, compressed, out_fname

# %% [markdown]
# **Problem 4**: Study the effect of compressing the input file at different ratios: 0.1, 0.5, 0.75, 0.9, 0.95, 0.99.
#
# Using the `OrderedDict` class from the [Python collections module](https://docs.python.org/3/library/collections.html#collections.OrderedDict), store the uncompressed signal as well as the compressed array and filename for each compression ratio.
#
# You will create an `OrderedDict` called `voices`, with:
#
# - keys: compression ratios
# - values: pairs of (x, filename) where x is the compressed audio and filename is the name of the compressed file.

# %%
from collections import OrderedDict

ratios=[0.1, 0.5, 0.75, 0.9, 0.95, 0.99]
voices=OrderedDict()
for ratio in ratios:
    _,_,compressed_audio,fname_compressed=compress_wav('data/voice.wav',ratio)
    voices[ratio]=(compressed_audio,fname_compressed)

# %% [markdown]
# **Problem 5**: Loop over the `voices` dict, and for each one generate an audio player as well as a spectrogram.  Observe how the spectrogram changes, and listen to each file.  At what ratio do you stop understanding the recording?

# %%
_,original=wavfile.read('data/voice.wav')
Audio('data/voice.wav')
specgram_cbar(original, title='Original')
for ratio in ratios:
    comp_audio,fname=voices[ratio]  
    Audio(fname)
    specgram_cbar(comp_audio, title='Compressed {0:.0%}'.format(ratio))
# Out:
# <p>data/voice.wav:</p>
# <audio controls>
#     <source src="files/data/voice.wav" type="audio/wav">
#
# Your browser does not support the Audio element; you can play
# <a href="files/data/voice.wav">this file</a> manually.
# </audio>
# <p>data/voice_comp_0.1.wav:</p>
# <audio controls>
#     <source src="files/data/voice_comp_0.1.wav" type="audio/wav">
#
# Your browser does not support the Audio element; you can play
# <a href="files/data/voice_comp_0.1.wav">this file</a> manually.
# </audio>
# <p>data/voice_comp_0.5.wav:</p>
# <audio controls>
#     <source src="files/data/voice_comp_0.5.wav" type="audio/wav">
#
# Your browser does not support the Audio element; you can play
# <a href="files/data/voice_comp_0.5.wav">this file</a> manually.
# </audio>
# <p>data/voice_comp_0.75.wav:</p>
# <audio controls>
#     <source src="files/data/voice_comp_0.75.wav" type="audio/wav">
#
# Your browser does not support the Audio element; you can play
# <a href="files/data/voice_comp_0.75.wav">this file</a> manually.
# </audio>
# <p>data/voice_comp_0.9.wav:</p>
# <audio controls>
#     <source src="files/data/voice_comp_0.9.wav" type="audio/wav">
#
# Your browser does not support the Audio element; you can play
# <a href="files/data/voice_comp_0.9.wav">this file</a> manually.
# </audio>
# <p>data/voice_comp_0.95.wav:</p>
# <audio controls>
#     <source src="files/data/voice_comp_0.95.wav" type="audio/wav">
#
# Your browser does not support the Audio element; you can play
# <a href="files/data/voice_comp_0.95.wav">this file</a> manually.
# </audio>
# <p>data/voice_comp_0.99.wav:</p>
# <audio controls>
#     <source src="files/data/voice_comp_0.99.wav" type="audio/wav">
#
# Your browser does not support the Audio element; you can play
# <a href="files/data/voice_comp_0.99.wav">this file</a> manually.
# </audio>

# %% [markdown]
# It's possible to hear the content of the message at 95% compression, but not at 99%. This is also clear from the spectrogram.

# %% [markdown]
# # #3: Armchair Astronomer
#
# Often times, people act as good sensors of the physical universe. We can use Google Trends data to help us determine some fundamental parameters of the Solar System.
#
# **Problem 1**: Using just the CSV file we created in the pandas lecture (`merged_data.csv`) and some frequency analysis tools in `scipy` to determine:
#
#    - the number of days in a year
#    - the period of the moon's orbit around the Earth
#
# Hint: `from scipy.signal.spectral import lombscargle` (you'll want to normalize your signal so it has a mean of zero.)

# %%
from datetime import datetime
import pandas as pd

# %%
df=pd.read_csv('data/merged_data.csv')
df
# Out:
#            Week  tennis  ice cream  full moon
# 0    2017-01-29      17         11         10
# 1    2017-02-05      13         11         40
# 2    2017-02-12      15         12         11
# 3    2017-02-19      16         13          9
# 4    2017-02-26      16         12         11
# ..          ...     ...        ...        ...
# 255  2021-12-19      12         14         31
# 256  2021-12-26      11         16          8
# 257  2022-01-02      13         14         11
# 258  2022-01-09      15         16         16
# 259  2022-01-16      20         15         49
#
# [260 rows x 4 columns]

# %%
weeks=df.get('Week')
time=np.array([datetime.strptime(w, '%Y-%m-%d').timestamp() for w in weeks])  # convert to unix time (seconds)
time-=time[0]  # we only care about time shift from week 0

moon=np.array(df.get('full moon'), dtype=np.float64)
tennis=np.array(df.get('tennis'), dtype=np.float64)
ice_cream=np.array(df.get('ice cream'), dtype=np.float64)

# %%
plt.figure()
plt.scatter(time, moon, label='Full moon')
plt.scatter(time, tennis, label='Tennis')
plt.scatter(time, ice_cream, label='Ice cream')
plt.legend()
plt.xlim(time.min(), time.max())
plt.ylim(0)
plt.xlabel('Time [s]')
plt.ylabel('Google Searches [arbitrary units]')
plt.show()

# %%
# generate some angular frequencies that are important for these searches
delta_omega=2*np.pi/time.max()  # make the frequency steps be order (observing time)^-1
omegas=np.linspace(delta_omega, len(time)*delta_omega, len(time))  # start > 0 to avoid division problems

# %%
ls_moon=signal.lombscargle(time, moon, omegas, precenter=True, normalize=True)
ls_tennis=signal.lombscargle(time, tennis, omegas, precenter=True, normalize=True)
ls_ice_cream=signal.lombscargle(time, ice_cream, omegas, precenter=True, normalize=True)

periods=2*np.pi/omegas  # convert angular frequencies to periods
periods/=3600*24  # convert to days

fig=plt.figure(figsize=(15,7))
ax1=fig.add_axes([0.,0., 1.,1.])
ax1.plot(periods, ls_moon, label='Full moon')
ax1.plot(periods, ls_tennis, label='Tennis')
ax1.plot(periods, ls_ice_cream, label='Ice cream')
ax1.legend()
ax1.set_xlabel('Period [days]')
ax1.set_ylabel('Google Searches [arbitrary units]')
ax1.set_ylim(0)
ax1.set_xlim(0, periods.max())
ax2=fig.add_axes([.3,.4,.6,.55])
ax2.plot(periods, ls_moon, label='Full moon')
ax2.plot(periods, ls_tennis, label='Tennis')
ax2.plot(periods, ls_ice_cream, label='Ice cream')
ax2.set_ylim(0)
ax2.set_xlim(-25, 500)
ax2.set_xlabel('Period [days]')
ax2.set_ylabel('Google Searches [arbitrary units]')
plt.show()

# %% [markdown]
# We see that the most important timescales for "tennis" and "ice cream" seem to line up. It is reasonable to believe this is a year, since "ice cream" likely is most popular ever summer (once per year) and "tennis" is probably searched for most during the annual US Open.

# %%
print(
    'Most important periods in days for ice cream are: {}'.format(
        np.array2string(periods[ls_ice_cream.argsort()[-5:][::-1]], separator=',', precision=2, floatmode='fixed')
    )
)
print(
    'Most important periods in days for tennis are: {}'.format(
        np.array2string(periods[ls_tennis.argsort()[-5:][::-1]], separator=',', precision=2, floatmode='fixed')
    )
)
# Out:
# Most important periods in days for ice cream are: [362.60,  7.14,  7.00,  7.28,181.30]
# Most important periods in days for tennis are: [362.60,  7.14,  7.28,181.30,  7.00]

# %% [markdown]
# A year is close to 363 days long.

# %% [markdown]
# We can do the same for the searches for "full moon".

# %%
print(
    'Most important periods in days for full moon: {}'.format(
        np.array2string(periods[ls_moon.argsort()[-5:][::-1]], separator=',', precision=2, floatmode='fixed')
    )
)
# Out:
# Most important periods in days for full moon: [ 9.16,29.72,13.33,14.74, 9.20]
